# %%
import pandas as pd
df = pd.read_csv("F:/MOCK_DATA.csv")
df
# Out:
#      id  first_name    last_name                          email  gender  \
# 0     1        Huey       Darrel           hdarrel0@cbsnews.com    Male
# 1     2     Saraann       Drugan         sdrugan1@angelfire.com  Female
# 2     3      Scotti        Petto        spetto2@nydailynews.com    Male
# 3     4        Noel     Hunstone           nhunstone3@upenn.edu  Female
# 4     5        Giff       McGrey                  gmcgrey4@g.co    Male
# 5     6        Neil    Waterland         nwaterland5@taobao.com    Male
# 6     7   Rosemarie     Tomblett            rtomblett6@xrea.com  Female
# 7     8     Everard      Colhoun            ecolhoun7@opera.com    Male
# 8     9         Sol         Jzak        sjzak8@biblegateway.com    Male
# 9    10      Laurie         Note  lnote9@scientificamerican.com    Male
# 10   11         Zea     Sizeland           zsizelanda@opera.com  Female
# 11   12       Perry       Pitson        ppitsonb@macromedia.com    Male
# ...

# %%
import pandas as pd
df = pd.read_csv("F:/MOCK_DATA.csv")
df.values[0]
# Out:
# array([1, 'Huey', 'Darrel', 'hdarrel0@cbsnews.com', 'Male',
#        '9.96.184.203'], dtype=object)

# %%
for row in df.values:
    print("id :", row[0], "first_name :", row[1])
# Out:
# id : 1 first_name : Huey
# id : 2 first_name : Saraann
# id : 3 first_name : Scotti
# id : 4 first_name : Noel
# id : 5 first_name : Giff
# id : 6 first_name : Neil
# id : 7 first_name : Rosemarie
# id : 8 first_name : Everard
# id : 9 first_name : Sol
# id : 10 first_name : Laurie
# id : 11 first_name : Zea
# id : 12 first_name : Perry
# id : 13 first_name : Ursa
# id : 14 first_name : Maryjo
# id : 15 first_name : Lucian
# id : 16 first_name : Gilli
# id : 17 first_name : Ardeen
# id : 18 first_name : Mercie
# id : 19 first_name : Vassily
# id : 20 first_name : Eugen
# id : 21 first_name : Garrek
# id : 22 first_name : Micheil
# id : 23 first_name : Slade
# id : 24 first_name : Tremaine
# id : 25 first_name : Daniel
# id : 26 first_name : Michaelina
# id : 27 first_name : Sascha
# id : 28 first_name : Morgan
# id : 29 first_name : Jecho
# id : 30 first_name : Free
# id : 31 first_name : Ulrika
# id : 32 first_name : Bond
# id : 33 first_name : Mac
# id : 34 first_name : Gillian
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.iat[1,4] # Accessing second row 5th element
# Out:
# 'Female'

# %%
df.loc[4]
# Out:
# id                        5
# first_name             Giff
# last_name            McGrey
# email         gmcgrey4@g.co
# gender                 Male
# ip_address    130.88.251.73
# Name: 4, dtype: object

# %%
df.loc[2][2]
# Out:
# 'Petto'

# %%
df
# Out:
#      id  first_name    last_name                          email  gender  \
# 0     1        Huey       Darrel           hdarrel0@cbsnews.com    Male
# 1     2     Saraann       Drugan         sdrugan1@angelfire.com  Female
# 2     3      Scotti        Petto        spetto2@nydailynews.com    Male
# 3     4        Noel     Hunstone           nhunstone3@upenn.edu  Female
# 4     5        Giff       McGrey                  gmcgrey4@g.co    Male
# 5     6        Neil    Waterland         nwaterland5@taobao.com    Male
# 6     7   Rosemarie     Tomblett            rtomblett6@xrea.com  Female
# 7     8     Everard      Colhoun            ecolhoun7@opera.com    Male
# 8     9         Sol         Jzak        sjzak8@biblegateway.com    Male
# 9    10      Laurie         Note  lnote9@scientificamerican.com    Male
# 10   11         Zea     Sizeland           zsizelanda@opera.com  Female
# 11   12       Perry       Pitson        ppitsonb@macromedia.com    Male
# ...

# %%
len(df)
# Out:
# 100

# %%
df.loc[100] = ['101','dumpal','koteswararao','dk@gmail.in','male','234.67.89.102']

# %%
df
# Out:
#       id  first_name     last_name                          email  gender  \
# 0    101      dumpal  koteswararao                    dk@gmail.in    male
# 1      2     Saraann        Drugan         sdrugan1@angelfire.com  Female
# 2      3      Scotti         Petto        spetto2@nydailynews.com    Male
# 3      4        Noel      Hunstone           nhunstone3@upenn.edu  Female
# 4      5        Giff        McGrey                  gmcgrey4@g.co    Male
# 5      6        Neil     Waterland         nwaterland5@taobao.com    Male
# 6      7   Rosemarie      Tomblett            rtomblett6@xrea.com  Female
# 7      8     Everard       Colhoun            ecolhoun7@opera.com    Male
# 8      9         Sol          Jzak        sjzak8@biblegateway.com    Male
# 9     10      Laurie          Note  lnote9@scientificamerican.com    Male
# 10    11         Zea      Sizeland           zsizelanda@opera.com  Female
# 11    12       Perry        Pitson        ppitsonb@macromedia.com    Male
# ...

# %%
import pandas as pd
df = pd.read_csv("F:/MOCK_DATA.csv")
df
# Out:
#      id  first_name    last_name                          email  gender  \
# 0     1        Huey       Darrel           hdarrel0@cbsnews.com    Male
# 1     2     Saraann       Drugan         sdrugan1@angelfire.com  Female
# 2     3      Scotti        Petto        spetto2@nydailynews.com    Male
# 3     4        Noel     Hunstone           nhunstone3@upenn.edu  Female
# 4     5        Giff       McGrey                  gmcgrey4@g.co    Male
# 5     6        Neil    Waterland         nwaterland5@taobao.com    Male
# 6     7   Rosemarie     Tomblett            rtomblett6@xrea.com  Female
# 7     8     Everard      Colhoun            ecolhoun7@opera.com    Male
# 8     9         Sol         Jzak        sjzak8@biblegateway.com    Male
# 9    10      Laurie         Note  lnote9@scientificamerican.com    Male
# 10   11         Zea     Sizeland           zsizelanda@opera.com  Female
# 11   12       Perry       Pitson        ppitsonb@macromedia.com    Male
# ...
